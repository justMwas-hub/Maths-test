# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mathsE data.csv")

# %%
df
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0            647         Ireland           77               0          Basic
# 1             41        Portugal           77               1          Basic
# 2            340        Portugal           77               1          Basic
# 3            641           Italy           77               0          Basic
# 4            669        Portugal           77               1          Basic
# ...          ...             ...          ...             ...            ...
# 9541         175           Italy         1497               1          Basic
# 9542         175           Italy         1514               0          Basic
# 9543         175           Italy         1521               0          Basic
# 9544         175           Italy         1526               1          Basic
# 9545         175           Italy         1549               0          Basic
#
#                         Topic  \
# ...

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Student Country", hue="Type of Answer")
plt.xticks(rotation=75);

# %%
df_no_key = df.drop("Keywords", axis = 1)

# %%
df_no_key
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0            647         Ireland           77               0          Basic
# 1             41        Portugal           77               1          Basic
# 2            340        Portugal           77               1          Basic
# 3            641           Italy           77               0          Basic
# 4            669        Portugal           77               1          Basic
# ...          ...             ...          ...             ...            ...
# 9541         175           Italy         1497               1          Basic
# 9542         175           Italy         1514               0          Basic
# 9543         175           Italy         1521               0          Basic
# 9544         175           Italy         1526               1          Basic
# 9545         175           Italy         1549               0          Basic
#
#                         Topic  \
# ...

# %%
df_no_key["Subtopic"].unique()
# Out:
# array(['Statistics', 'Derivatives', 'Domain, Image and Graphics',
#        'Limits and Continuity', 'Linear Systems',
#        'Algebraic expressions, Equations, and Inequalities',
#        'Matrices and Determinants', 'Differential Equations',
#        'Partial Differentiation', 'Nonlinear Optimization',
#        'Integration Techniques', 'Linear Transformations',
#        'Linear Optimization', 'Probability ', 'Vector Spaces',
#        'Complex Numbers', 'Graph Theory', 'Elementary Geometry',
#        'Double Integration', 'Analytic Geometry',
#        'Eigenvalues and Eigenvectors', 'Numerical Methods', 'Set Theory',
#        'Definite Integrals'], dtype=object)

# %%
df_no_key.to_csv("mathE_no_keywords.csv", index=False)

# %%
df = pd.read_csv("mathE_no_keywords.csv")

# %%
df
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0            647         Ireland           77               0          Basic
# 1             41        Portugal           77               1          Basic
# 2            340        Portugal           77               1          Basic
# 3            641           Italy           77               0          Basic
# 4            669        Portugal           77               1          Basic
# ...          ...             ...          ...             ...            ...
# 9541         175           Italy         1497               1          Basic
# 9542         175           Italy         1514               0          Basic
# 9543         175           Italy         1521               0          Basic
# 9544         175           Italy         1526               1          Basic
# 9545         175           Italy         1549               0          Basic
#
#                         Topic  \
# ...

# %%
df_nums = df.select_dtypes(exclude="object")
df_obj = df.select_dtypes(include="object")

# %%
df_nums
# Out:
#       Student ID  Question ID  Type of Answer
# 0            647           77               0
# 1             41           77               1
# 2            340           77               1
# 3            641           77               0
# 4            669           77               1
# ...          ...          ...             ...
# 9541         175         1497               1
# 9542         175         1514               0
# 9543         175         1521               0
# 9544         175         1526               1
# 9545         175         1549               0
#
# [9546 rows x 3 columns]

# %%
df_obj
# Out:
#      Student Country Question Level                    Topic  \
# 0            Ireland          Basic               Statistics
# 1           Portugal          Basic               Statistics
# 2           Portugal          Basic               Statistics
# 3              Italy          Basic               Statistics
# 4           Portugal          Basic               Statistics
# ...              ...            ...                      ...
# 9541           Italy          Basic          Complex Numbers
# 9542           Italy          Basic          Complex Numbers
# 9543           Italy          Basic  Fundamental Mathematics
# 9544           Italy          Basic  Fundamental Mathematics
# 9545           Italy          Basic  Fundamental Mathematics
#
#                                                Subtopic
# 0                                            Statistics
# 1                                            Statistics
# 2                                            Statistics
# ...

# %%
df_obj = pd.get_dummies(df_obj, drop_first=True)

# %%
final_df = pd.concat([df_nums, df_obj], axis=1)

# %%
final_df
# Out:
#       Student ID  Question ID  Type of Answer  Student Country_Italy  \
# 0            647           77               0                      0
# 1             41           77               1                      0
# 2            340           77               1                      0
# 3            641           77               0                      1
# 4            669           77               1                      0
# ...          ...          ...             ...                    ...
# 9541         175         1497               1                      1
# 9542         175         1514               0                      1
# 9543         175         1521               0                      1
# 9544         175         1526               1                      1
# 9545         175         1549               0                      1
#
#       Student Country_Lithuania  Student Country_Portugal  \
# 0                             0                         0
# ...

# %%
final_df.to_csv("mathE_with_dummies.csv", index=False)

# %%
final_df.describe().transpose()
# Out:
#                                             count        mean         std  \
# Student ID                                 9546.0  775.402263  460.590559
# Question ID                                9546.0  478.912319  249.244061
# Type of Answer                             9546.0    0.468259    0.499018
# Student Country_Italy                      9546.0    0.142259    0.349333
# Student Country_Lithuania                  9546.0    0.151163    0.358226
# Student Country_Portugal                   9546.0    0.575634    0.494272
# Student Country_Romania                    9546.0    0.006285    0.079035
# Student Country_Russian Federation         9546.0    0.011209    0.105283
# Student Country_Slovenia                   9546.0    0.079091    0.269894
# Student Country_Spain                      9546.0    0.002933    0.054082
# Question Level_Basic                       9546.0    0.821705    0.382781
# Topic_Complex Numbers                      9546.0    0.062016    0.241196
# ...
