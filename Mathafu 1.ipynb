# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mathsE data.csv")

# %%
df
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0            647         Ireland           77               0          Basic
# 1             41        Portugal           77               1          Basic
# 2            340        Portugal           77               1          Basic
# 3            641           Italy           77               0          Basic
# 4            669        Portugal           77               1          Basic
# ...          ...             ...          ...             ...            ...
# 9541         175           Italy         1497               1          Basic
# 9542         175           Italy         1514               0          Basic
# 9543         175           Italy         1521               0          Basic
# 9544         175           Italy         1526               1          Basic
# 9545         175           Italy         1549               0          Basic
#
#                         Topic  \
# ...

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Student Country")
plt.xticks(rotation=75);

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Topic")
plt.xticks(rotation=75);

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Question Level")
plt.xticks(rotation=75);

# %%
sns.pairplot(df)

# %%
#df["Keywords"].unique()

# %%
df[df["Question Level"] == "Advanced"]
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 85          1557        Portugal           86               1       Advanced
# 86           552        Portugal           87               0       Advanced
# 87          1557        Portugal           87               1       Advanced
# 88          1557        Portugal           87               0       Advanced
# 89          1557        Portugal           87               0       Advanced
# ...          ...             ...          ...             ...            ...
# 9108         376        Portugal         1056               0       Advanced
# 9117          37        Portugal         1066               1       Advanced
# 9118          37        Portugal         1067               0       Advanced
# 9125          37        Portugal         1084               1       Advanced
# 9126          37        Portugal         1084               1       Advanced
#
# ...

# %%
df["Subtopic"].value_counts()
# Out:
# Vector Spaces                                         2749
# Linear Transformations                                2127
# Complex Numbers                                        592
# Algebraic expressions, Equations, and Inequalities     496
# Linear Systems                                         420
# Analytic Geometry                                      358
# Statistics                                             340
# Elementary Geometry                                    322
# Derivatives                                            317
# Numerical Methods                                      310
# Matrices and Determinants                              300
# Partial Differentiation                                262
# Eigenvalues and Eigenvectors                           130
# Probability                                            128
# Nonlinear Optimization                                 126
# Integration Techniques                                 111
# ...

# %%
df["Topic"].value_counts()
# Out:
# Linear Algebra                         5726
# Fundamental Mathematics                 818
# Complex Numbers                         592
# Differentiation                         579
# Analytic Geometry                       358
# Statistics                              340
# Numerical Methods                       310
# Optimization                            182
# Real Functions of a single variable     164
# Integration                             144
# Probability                             128
# Differential Equations                  108
# Graph Theory                             55
# Set Theory                               42
# Name: Topic, dtype: int64

# %%
df[(df["Question Level"] == "Advanced") & (df["Type of Answer"] == 1)]
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 85          1557        Portugal           86               1       Advanced
# 87          1557        Portugal           87               1       Advanced
# 330           91       Lithuania          117               1       Advanced
# 383           91       Lithuania          121               1       Advanced
# 402          422        Portugal          124               1       Advanced
# ...          ...             ...          ...             ...            ...
# 9106         376        Portugal         1054               1       Advanced
# 9107         376        Portugal         1056               1       Advanced
# 9117          37        Portugal         1066               1       Advanced
# 9125          37        Portugal         1084               1       Advanced
# 9126          37        Portugal         1084               1       Advanced
#
#                                     Topic  \
# ...

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Question Level", hue="Type of Answer")
plt.xticks(rotation=75);

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Topic", hue="Type of Answer")
plt.xticks(rotation=75);

# %%
df["Type of Answer"].value_counts()
# Out:
# 0    5076
# 1    4470
# Name: Type of Answer, dtype: int64

# %%
plt.figure(figsize=(8,6), dpi=150)
sns.countplot(data=df, x="Subtopic", hue="Type of Answer")
plt.xticks(rotation=90);

# %%
df.groupby(["Topic", "Subtopic"]).size()
# Out:
# Topic                                Subtopic
# Analytic Geometry                    Analytic Geometry                                      358
# Complex Numbers                      Complex Numbers                                        592
# Differential Equations               Differential Equations                                 108
# Differentiation                      Derivatives                                            317
#                                      Partial Differentiation                                262
# Fundamental Mathematics              Algebraic expressions, Equations, and Inequalities     496
#                                      Elementary Geometry                                    322
# Graph Theory                         Graph Theory                                            55
# Integration                          Definite Integrals                                      15
# ...

# %%
df.groupby(["Question Level", "Topic"]).size()
# Out:
# Question Level  Topic
# Advanced        Analytic Geometry                        50
#                 Complex Numbers                         264
#                 Differential Equations                    2
#                 Differentiation                          25
#                 Fundamental Mathematics                  63
#                 Graph Theory                             20
#                 Integration                              19
#                 Linear Algebra                         1188
#                 Optimization                              6
#                 Probability                              23
#                 Real Functions of a single variable      42
# Basic           Analytic Geometry                       308
#                 Complex Numbers                         328
#                 Differential Equations                  106
#                 Differentiation                         554
# ...

# %%
df.groupby(["Question Level", "Topic", "Subtopic"]).size()
# Out:
# Question Level  Topic                                Subtopic
# Advanced        Analytic Geometry                    Analytic Geometry                                       50
#                 Complex Numbers                      Complex Numbers                                        264
#                 Differential Equations               Differential Equations                                   2
#                 Differentiation                      Derivatives                                              4
#                                                      Partial Differentiation                                 21
#                 Fundamental Mathematics              Algebraic expressions, Equations, and Inequalities      25
#                                                      Elementary Geometry                                     38
#                 Graph Theory                         Graph Theory                                            20
# ...

# %%
df["Question Level"].nunique()
# Out:
# 2

# %%
df[(df["Question Level"] == "Advanced") & (df["Topic"] == "Linear Algebra")]
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 402          422        Portugal          124               1       Advanced
# 414           90       Lithuania          126               0       Advanced
# 415         1351        Portugal          126               1       Advanced
# 416          422        Portugal          126               1       Advanced
# 417          633           Italy          126               0       Advanced
# ...          ...             ...          ...             ...            ...
# 8601         599           Italy          854               1       Advanced
# 8602         411        Portugal          856               1       Advanced
# 8603         599           Italy          856               1       Advanced
# 8604        1517        Portugal          857               1       Advanced
# 8605         599           Italy          857               1       Advanced
#
# ...

# %%
df[(df["Question Level"] == "Advanced") & (df["Subtopic"] == "Matrices and Determinants")]
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 402          422        Portugal          124               1       Advanced
# 414           90       Lithuania          126               0       Advanced
# 415         1351        Portugal          126               1       Advanced
# 416          422        Portugal          126               1       Advanced
# 417          633           Italy          126               0       Advanced
# 429           90       Lithuania          128               0       Advanced
# 430          415        Portugal          128               0       Advanced
# 431          422        Portugal          128               1       Advanced
# 432          633           Italy          128               1       Advanced
# 459           90       Lithuania          132               0       Advanced
# 460          415        Portugal          132               1       Advanced
# ...

# %%
df[(df["Question Level"] == "Basic") & (df["Subtopic"] == "Matrices and Determinants")]
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 385          128       Lithuania          122               0          Basic
# 386          455        Portugal          122               0          Basic
# 387          524        Portugal          122               1          Basic
# 388          509        Portugal          122               1          Basic
# 389          511        Portugal          122               1          Basic
# ...          ...             ...          ...             ...            ...
# 7543         524        Portugal          653               1          Basic
# 7544          71        Portugal          653               0          Basic
# 7545          52        Portugal          653               1          Basic
# 7546          72        Portugal          653               0          Basic
# 7547         311         Ireland          653               1          Basic
#
# ...

# %%
df["Keywords"].value_counts()
# Out:
# Linear application,Linearity                                                443
# Subspace,Linear combination,Span                                            401
# Simplify expressions                                                        401
# Linear independence,Span,Linear dependence                                  399
# Range,Kernel                                                                344
#                                                                            ...
# Fundamental theorem of Calculus,Direct integrals                              1
# Trigonometric rules,Power rule                                                1
# Simplex method,Linear programming,Assignment problem,Excel solver add-in      1
# Tree,Simple graph,Spanning tree,Path                                          1
# Cauchy problem,Exact differential form                                        1
# Name: Keywords, Length: 365, dtype: int64
